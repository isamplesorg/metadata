# %% [markdown]
# Script to generate a list of columns in GEOME that have been required in at least one project.

# %%
import logging
import pandas as pd
import numpy as np
import requests
import concurrent.futures

RULE_REQUIRED = "RequiredValue"
ERROR_LEVEL = "ERROR"
GEOME_API = "https://api.geome-db.org/v1"
TIMEOUT = 30 #seconds
logging.basicConfig(level=logging.INFO)

def processGeomeConfig(doc, proj_id=0, title="network"):
    res = []
    defns = {}
    for entity in doc.get("entities", []):
        alias = entity.get("conceptAlias")
        cols = set()
        # Get the required columns
        for r in entity.get("rules"):
            if r.get("name") == RULE_REQUIRED and r.get("level") == ERROR_LEVEL:
                cols.update(r.get("columns"))
        # Get column definition info
        for a in entity.get("attributes", []):
            cname = a.get("column")
            if cname in cols:
                adef = {
                    "definedBy": a.get("definedBy"),
                    "group": a.get("group"),
                    "definition": a.get("definition")
                }
                defns[cname] = adef
        for c in cols:
            #row = (alias, c, proj_id, title)
            row = (alias, c, proj_id)
            res.append(row)
    return res, defns

def getProjectConfig(project_id):
    url = f"{GEOME_API}/projects/{project_id}/config"
    response = requests.get(url, timeout=TIMEOUT)
    cfgdoc = response.json()
    return cfgdoc


def processProject(project_id, project_title):
    doc = getProjectConfig(project_id)
    res, defns = processGeomeConfig(doc, proj_id=project_id, title=project_title)
    return res, defns

def processProjects():
    L = logging.getLogger("loader")
    url = f"{GEOME_API}/projects/"
    params = {"includePublic": "true", "admin": "false"}
    response = requests.get(url, params=params, timeout=TIMEOUT)
    projects = response.json()
    res = []
    definitions = {}
    with concurrent.futures.ThreadPoolExecutor(max_workers=20) as executor:
        futures = []
        for project in projects:
            proj_id = project.get("projectId")
            title = project.get("projectTitle")            
            L.info(f"Loading: {proj_id} - {title}")
            futures.append(executor.submit(processProject, proj_id, title))
        for future in concurrent.futures.as_completed(futures):
            reqs, defns = future.result()
            res += reqs
            definitions.update(defns)
    return res, definitions


required = []
response = requests.get(f"{GEOME_API}/network/1/config", timeout=TIMEOUT)
network_config = response.json()
required, definitions = processGeomeConfig(network_config)
preq, pdefns = processProjects()
required += preq
definitions.update(pdefns)
# Out:
# INFO:loader:Loading: 114 - Collins Lab
# INFO:loader:Loading: 125 - European ARMS project
# INFO:loader:Loading: 131 - Amalda_mitochondria_genomes
# INFO:loader:Loading: 147 - Pillar Point - CALeDNA
# INFO:loader:Loading: 355 - NMNH TEST PROJECT
# INFO:loader:Loading: 183 - DiSSCo
# INFO:loader:Loading: 41 - Zostera capensis pooled RADseq
# INFO:loader:Loading: 332 - HIV PROJECT
# INFO:loader:Loading: 90 - Bionetwork
# INFO:loader:Loading: 61 - Smithsonian DROP Project
# INFO:loader:Loading: 67 - Cairns LAB
# INFO:loader:Loading: 83 - Windsor LAB
# INFO:loader:Loading: 376 - Early presence of Batrachochytrium dendrobatidis in Mexico with a contemporary dominance of the global panzootic lineage
# INFO:loader:Loading: 303 - Tata PowerPoint
# INFO:loader:Loading: 168 - Bighorn_RAD_Parentage_2018
# INFO:loader:Loading: 158 - Candida ITS
# INFO:loader:Loading: 181 - Mexican_gray_wolf_RAD_Parentage_2018
# INFO:loader:Loading: 89 - Mekong River
# INFO:loader:Loading: 118 - Crandall Lab
# INFO:loader:Loading: 13 - Genetic diversity of coral reef damselfish feeding guilds
# INFO:loader:Loading: 40 - Kuroshio Current
# INFO:loader:Loading: 68 - CMPI
# INFO:loader:Loading: 69 - Harasewych LAB
# INFO:loader:Loading: 70 - INDIAN RIVER LAGOON
# INFO:loader:Loading: 71 - Lemaitre LAB
# INFO:loader:Loading: 77 - Osborn LAB
# INFO:loader:Loading: 78 - PEER Deadheads
# INFO:loader:Loading: 154 - ITS
# INFO:loader:Loading: 201 - Australian intertidal fish
# INFO:loader:Loading: 191 - Walleye GT-seq -second trial
# INFO:loader:Loading: 284 - SNAPS: Student Network for Amphibian Pathogen Surveillance
# INFO:loader:Loading: 305 - Retrospective SRA Datathon
# INFO:loader:Loading: 75 - Moorea Biocode
# INFO:loader:Loading: 80 - PIRE ARMS
# INFO:loader:Loading: 309 - Global Silky Shark Pool-Seq Assessment
# INFO:loader:Loading: 81 - Strong LAB
# INFO:loader:Loading: 79 - Phillips LAB
# INFO:loader:Loading: 300 - Bd-Maps Legacy Project
# INFO:loader:Loading: 328 - Using multi-species seascape genomics to conserve areas of evolutionary importance
# INFO:loader:Loading: 190 - 1904 - Lake Erie walleye MSA
# INFO:loader:Loading: 291 - AmphibiaWeb Disease Portal
# INFO:loader:Loading: 220 - Apostle Islands
# INFO:loader:Loading: 348 - Population genomics of marine fisheries
# INFO:loader:Loading: 212 - Asymmetrical gene-flow in five co-distributed syngnathids explained by ocean currents and rafting propensity
# INFO:loader:Loading: 64 - MISE University of the Ryukyus
# INFO:loader:Loading: 76 - Norenburg LAB
# INFO:loader:Loading: 248 - Investigating the chytrid presence in a non-native amphibian in Cambridge, England
# INFO:loader:Loading: 293 - Gaither Lab
# INFO:loader:Loading: 319 - Atelopus patazensis
# INFO:loader:Loading: 316 - Sponging up Diversity
# INFO:loader:Loading: 242 - Kosnipata
# INFO:loader:Loading: 337 - Host-symbiont coevolution, cryptic structure, and bleaching susceptibility, in a coral species complex (Scleractinia; Poritidae).
# INFO:loader:Loading: 323 - Pfeiffer LAB
# INFO:loader:Loading: 72 - Meyer ARMS
# INFO:loader:Loading: 240 - Japumayo
# INFO:loader:Loading: 365 - A seasonal follow up of Batrachochytrium dendrobatidis (Bd) and amphibian species detection in Norwegian water- courses using environmental DNA
# INFO:loader:Loading: 366 - Bsal Negative Round Up
# INFO:loader:Loading: 295 - The Type Locality Project: collecting genomic-quality, topotypic vouchers and training the next generation of specimen-based researchers
# INFO:loader:Loading: 1 - Diversity of the IndoPacific
# INFO:loader:Loading: 221 - Widespread presence and high prevalence of Batrachochytrium dendrobatidis in Gabon
# INFO:loader:Loading: 290 - Fungal infection, decline, and persistence in the only obligate troglodytic Neotropical salamander
# INFO:loader:Loading: 317 - Identification and development of DNA barcodes on lobster (Panulirus spp.)
# INFO:loader:Loading: 361 - RESERVEBENEFIT
# INFO:loader:Loading: 344 - Tibetan Antelope_Microbiome_Hormone
# INFO:loader:Loading: 85 - SI Barcoding CBOL
# INFO:loader:Loading: 73 - Meyer Biocube
# INFO:loader:Loading: 327 - CALeDNA
# INFO:loader:Loading: 339 - Boardman Lake eDNA metabarcoding
# INFO:loader:Loading: 357 - CoGeDiv: Comparative Genomic Analysis of Species Divergence
# INFO:loader:Loading: 232 - FuTRES Sample Project
# INFO:loader:Loading: 82 - USAID INDO
# INFO:loader:Loading: 222 - Bd swabs from all Bd projects conducted by Dr Cori Richards Zawacki and collaborators
# INFO:loader:Loading: 282 - Florida Museum Environmental Archaeology Program Comparative Collection Data
# INFO:loader:Loading: 286 - Cryptic diversity of a widespread global pathogen reveals expanded threats to amphibian conservation
# INFO:loader:Loading: 74 - Meyer LAB
# INFO:loader:Loading: 223 - Batrachochytrium dendrobatidis invasion on California Islands
# INFO:loader:Loading: 243 - Survey of Pathogenic Chytrid Fungi (Batrachochytrium salamandrivorans) in Salamanders from Three Mountain Ranges in Europe and the Americas
# INFO:loader:Loading: 44 - Smithsonian BOEM Project
# INFO:loader:Loading: 255 - Batrachochytrium dendrobatidis in amphibian museum specimens from Costa Rica (UCR)
# INFO:loader:Loading: 254 - Sierra Nevada Retrospective Analysis
# INFO:loader:Loading: 241 - Is Chytridiomycosis an Emerging Infectious Disease in Asia?
# INFO:loader:Loading: 244 - Pathogen invasion and non-epizootic dynamics in Pacific newts in California over the last century
# INFO:loader:Loading: 354 - Bsal Consortium of Germany
# INFO:loader:Loading: 292 - USGS National Survey for the Amphibian Chytrid Fungus Batrachochytrium salamandrivorans

# %%
df = pd.DataFrame.from_records(required, columns=["record_alias", "column_name", "project_id"])
df
# Out:
#      record_alias       column_name  project_id
# 0           Event           country           0
# 1           Event     yearCollected           0
# 2           Event          locality           0
# 3          Sample           eventID           0
# 4     Diagnostics  materialSampleID           0
# ...           ...               ...         ...
# 1863  Diagnostics  materialSampleID         292
# 1864  Diagnostics      diagnosticID         292
# 1865  Diagnostics   diseaseDetected         292
# 1866  Diagnostics             fatal         292
# 1867  Diagnostics     diseaseTested         292
#
# [1868 rows x 3 columns]

# %%
dfg = df.groupby(by=["record_alias","column_name"]).count()
pd.options.display.float_format = '{:,.0f}'.format
p = pd.pivot_table(df, values="project_id", index="column_name", columns="record_alias", 
                   aggfunc=lambda x: len(x)).fillna(0)
p
# Out:
# record_alias                   Diagnostics  Event  Event_Photo  Sample  \
# column_name
# basisOfRecord                            0      0            0      26
# collectorList                            0     23            0       0
# coordinateUncertaintyInMeters            0      1            0       0
# country                                  0     84            0       0
# decimalLatitude                          0     60            0       0
# decimalLongitude                         0     60            0       0
# designDescription                        0      0            0       0
# diagnosticID                            28      0            0       0
# diseaseDetected                         23      0            0       0
# diseaseTested                           23      0            0       0
# eventEnteredBy                           0     22            0       0
# eventID                                  0     83           22      84
# fatal                                   23      0            0       0
# filenames                                0      0            0       0
# genus                                    0      0            0      23
# georeferenceProtocol                     0      1            0       0
# habitat                                  0      1            0       0
# identifier                               0      0            0       0
# institutionCode                          0      0            0      25
# instrumentModel                          0      0            0       0
# kingdom                                  0      0            0       3
# libraryLayout                            0      0            0       0
# librarySelection                         0      0            0       0
# librarySource                            0      0            0       0
# libraryStrategy                          0      0            0       0
# locality                                 0     84            0       0
# materialSampleID                        28      0            0      83
# measurementMethod                        3      0            0       0
# measurementType                          3      0            0       0
# measurementUnit                          3      0            0       0
# measurementValue                         3      0            0       0
# photoID                                  0      0           23       0
# phylum                                   0      0            0      25
# platform                                 0      0            0       0
# principalInvestigator                    0     36            0       0
# sampleEnteredBy                          0      0            0      23
# sampleType                              23      0            0       0
# samplingProtocol                         0      3            0       0
# scientificName                           0      0            0       6
# sequence                                 0      0            0       0
# specificEpithet                          0      0            0      23
# subProject                               0      0            0       1
# tissueID                                 0      0            0       0
# tissuePlate                              0      0            0       0
# tissueWell                               0      0            0       0
# yearCollected                            0     84            0       0
#
# record_alias                   Sample_Photo  Tissue  fastaSequence  \
# column_name
# basisOfRecord                             0       0              0
# collectorList                             0       0              0
# coordinateUncertaintyInMeters             0       0              0
# country                                   0       0              0
# decimalLatitude                           0       0              0
# decimalLongitude                          0       0              0
# designDescription                         0       0              0
# diagnosticID                              0       0              0
# diseaseDetected                           0       0              0
# diseaseTested                             0       0              0
# eventEnteredBy                            0       0              0
# eventID                                   0       0              0
# fatal                                     0       0              0
# filenames                                 0       0              0
# genus                                     0       0              0
# georeferenceProtocol                      0       0              0
# habitat                                   0       0              0
# identifier                                0       0             41
# institutionCode                           0       0              0
# instrumentModel                           0       0              0
# kingdom                                   0       0              0
# libraryLayout                             0       0              0
# librarySelection                          0       0              0
# librarySource                             0       0              0
# libraryStrategy                           0       0              0
# locality                                  0       0              0
# materialSampleID                         22      56              0
# measurementMethod                         0       0              0
# measurementType                           0       0              0
# measurementUnit                           0       0              0
# measurementValue                          0       0              0
# photoID                                  23       0              0
# phylum                                    0       0              0
# platform                                  0       0              0
# principalInvestigator                     0       0              0
# sampleEnteredBy                           0       0              0
# sampleType                                0       0              0
# samplingProtocol                          0       0              0
# scientificName                            0       0              0
# sequence                                  0       0             41
# specificEpithet                           0       0              0
# subProject                                0       0              0
# tissueID                                  0       1             40
# tissuePlate                               0       3              0
# tissueWell                                0       3              0
# yearCollected                             0       0              0
#
# record_alias                   fastqMetadata
# column_name
# basisOfRecord                              0
# collectorList                              0
# coordinateUncertaintyInMeters              0
# country                                    0
# decimalLatitude                            0
# decimalLongitude                           0
# designDescription                         57
# diagnosticID                               0
# diseaseDetected                            0
# diseaseTested                              0
# eventEnteredBy                             0
# eventID                                    0
# fatal                                      0
# filenames                                 57
# genus                                      0
# georeferenceProtocol                       0
# habitat                                    0
# identifier                                57
# institutionCode                            0
# instrumentModel                           57
# kingdom                                    0
# libraryLayout                             57
# librarySelection                          57
# librarySource                             57
# libraryStrategy                           57
# locality                                   0
# materialSampleID                           0
# measurementMethod                          0
# measurementType                            0
# measurementUnit                            0
# measurementValue                           0
# photoID                                    0
# phylum                                     0
# platform                                  57
# principalInvestigator                      0
# sampleEnteredBy                            0
# sampleType                                 0
# samplingProtocol                           0
# scientificName                             0
# sequence                                   0
# specificEpithet                            0
# subProject                                 0
# tissueID                                  56
# tissuePlate                                0
# tissueWell                                 0
# yearCollected                              0

# %%
import textwrap
for k,d in definitions.items():
    print(f"{k}")
    print(f"       group: {d.get('group') or ''}")
    print(f"   definedBy: {d.get('definedBy') or ''}")
    print(f"  definition: {textwrap.fill(d.get('definition') or '', 70, subsequent_indent='              ')}")
    print("")
# Out:
# country
#        group:
#    definedBy: http://rs.tdwg.org/dwc/terms/country
#   definition: The name of the country or major administrative unit in which the
#               Location occurs.
#
# locality
#        group:
#    definedBy: http://rs.tdwg.org/dwc/terms/locality
#   definition: The specific description of the place. Less specific geographic
#               information can be provided in other geographic terms
#               (higherGeography, continent, country, stateProvince,
#               county, municipality, waterBody, island, islandGroup).
#               This term may contain information modified from the
#               original to correct perceived errors or standardize the
#               description.
#
# yearCollected
#        group:
#    definedBy: urn:yearCollected
#   definition: The year the collecting event took place
#
# eventID
#        group: Record and Owner Details
#    definedBy: http://rs.tdwg.org/dwc/terms/eventID
#   definition: The collector's event identifier.
#
# diagnosticID
#        group:
#    definedBy: http://rs.tdwg.org/dwc/terms/measurementID
#   definition: The identifier for the diagnostic procedure.
#
# materialSampleID
#        group:
#    definedBy: http://rs.tdwg.org/dwc/terms/MaterialSampleID
#   definition: The collector's specimen number. This number must be unique among the
#               IDs within the expedition.
#
# photoID
#        group:
#    definedBy:
#   definition: identifier for the photo
#
# sequence
#        group:
#    definedBy:
#   definition: Sequence data for the material sample.
#
# identifier
#        group:
#    definedBy:
#   definition:
#
# libraryLayout
#        group:
#    definedBy:
#   definition:
#
# libraryStrategy
#        group:
#    definedBy:
#   definition:
#
# librarySource
#        group:
#    definedBy:
#   definition:
#
# librarySelection
#        group:
#    definedBy:
#   definition:
#
# platform
#        group:
#    definedBy:
#   definition:
#
# instrumentModel
#        group:
#    definedBy:
#   definition:
#
# designDescription
#        group:
#    definedBy:
#   definition:
#
# filenames
#        group:
#    definedBy:
#   definition: List of filenames to be uploaded to NCBI Genbank SRA
#
# institutionCode
#        group: Protocol and Storage Details
#    definedBy: http://rs.tdwg.org/dwc/terms/ownerInstitutionCode
#   definition: The name (or acronym) in use by the institution having custody of the
#               object(s) or information referred to in the record.
#
# sampleEnteredBy
#        group: Record and Owner Details
#    definedBy: urn:EnteredBy
#   definition: The name of the person that entered the data.
#
# phylum
#        group: Taxonomy and Life History
#    definedBy: http://rs.tdwg.org/dwc/terms/phylum
#   definition: The full scientific name of the phylum in which the taxon is
#               classified
#
# decimalLatitude
#        group:
#    definedBy: http://rs.tdwg.org/dwc/terms/decimalLatitude
#   definition: The geographic latitude (in decimal degrees, using the spatial
#               reference system given in geodeticDatum) of the
#               geographic center of a Location. Positive values are
#               north of the Equator, negative values are south of it.
#               Legal values lie between -90 and 90, inclusive.
#
# decimalLongitude
#        group:
#    definedBy: http://rs.tdwg.org/dwc/terms/decimalLongitude
#   definition: The geographic longitude (in decimal degrees, using the spatial
#               reference system given in geodeticDatum) of the
#               geographic center of a Location. Positive values are
#               east of the Greenwich Meridian, negative values are west
#               of it. Legal values lie between -180 and 180, inclusive.
#
# eventEnteredBy
#        group:
#    definedBy: urn:enteredBy
#   definition: The name of the person entering the data.
#
# tissueID
#        group:
#    definedBy: urn:tissueID
#   definition:
#
# kingdom
#        group: Taxonomy and Life History
#    definedBy: http://rs.tdwg.org/dwc/terms/kingdom
#   definition: The full scientific name of the kingdom in which the taxon is
#               classified.
#
# scientificName
#        group: Diagnostics and Traits
#    definedBy: http://rs.tdwg.org/dwc/terms/scientificName
#   definition: scientificName as the lowest taxon identified
#
# tissuePlate
#        group:
#    definedBy: urn:plateID
#   definition: The name of the plate.  Typically this is a 96 well plat for Biocode
#               projects
#
# tissueWell
#        group:
#    definedBy: urn:wellID
#   definition: The well location in the plate
#
# principalInvestigator
#        group:
#    definedBy: urn:principalInvestigator
#   definition: Firstname Lastname (the PI on the grant that generated this data)
#
# collectorList
#        group:
#    definedBy: http://rs.tdwg.org/dwc/terms/recordedBy
#   definition: A list (concatenated and separated) of names of people, groups, or
#               organizations responsible for recording the original
#               Occurrence. The primary collector or observer,
#               especially one who applies a personal identifier
#               (recordNumber), should be listed first.  Name separation
#               should use the pipe ('|') symbol
#
# basisOfRecord
#        group: Record and Owner Details
#    definedBy: http://rs.tdwg.org/dwc/terms/basisOfRecord
#   definition: The specific nature of the data record.  Examples include
#               PreservedSpecimen, FossilSpecimen, LivingSpecimen,
#               MaterialSample, Event, HumanObservation,
#               MachineObservation, Taxon, Occurrence
#
# genus
#        group: Taxonomy and Life History
#    definedBy: http://rs.tdwg.org/dwc/terms/genus
#   definition: The full scientific name of the genus in which the taxon is
#               classified. This should be a text string starting with a
#               capital letter. If Unknown, then add note of its next
#               closest taxonomic level of identification in
#               taxonRemarks
#
# specificEpithet
#        group: Taxonomy and Life History
#    definedBy: http://rs.tdwg.org/dwc/terms/specificEpithet
#   definition: The full scientific name of the specificEpithet in which the taxon is
#               classified. This should be a text string in lower case.
#               If unknown, use "sp." (without quotes).
#
# sampleType
#        group: Diagnostics and Traits
#    definedBy:
#   definition: Type of sample tested: eg, swabbing, blood, skin, liver
#
# diseaseTested
#        group: Diagnostics and Traits
#    definedBy:
#   definition: Controlled vocabulary: Bd, Bsal, Bd+Bsal, Other
#
# diseaseDetected
#        group: Diagnostics and Traits
#    definedBy:
#   definition: Result of disease testing: True=Positive, False=Negative, No
#               Confidence=Ambiguous
#
# fatal
#        group: Diagnostics and Traits
#    definedBy:
#   definition: At time of sampling, presumed cause of death to be diseaseTested, mark
#               [FALSE] if unknown
#
# samplingProtocol
#        group:
#    definedBy: http://rs.tdwg.org/dwc/terms/samplingProtocol
#   definition: The name of, reference to, or description of the method or protocol
#               used in acquiring the materialSample.
#
# measurementMethod
#        group: Diagnostics and Traits
#    definedBy: http://rs.tdwg.org/dwc/terms/measurementMethod
#   definition: A description of or reference to (publication, URI) the method or
#               protocol used to determine the measurement, fact,
#               characteristic, or assertion.
#
# measurementUnit
#        group: Diagnostics and Traits
#    definedBy: http://rs.tdwg.org/dwc/terms/measurementUnit
#   definition: The units associated with the measurementValue.
#
# measurementType
#        group: Diagnostics and Traits
#    definedBy: http://rs.tdwg.org/dwc/terms/measurementType
#   definition: The nature of the measurement, fact, characteristic, or assertion.
#
# measurementValue
#        group: Diagnostics and Traits
#    definedBy: http://rs.tdwg.org/dwc/terms/measurementValue
#   definition: The value of the measurement, fact, characteristic, or assertion.
#
# coordinateUncertaintyInMeters
#        group:
#    definedBy: http://rs.tdwg.org/dwc/terms/coordinateUncertaintyInMeters
#   definition: The horizontal distance (in meters) from the given decimalLatitude and
#               decimalLongitude describing the smallest circle
#               containing the whole of the Location. Leave the value
#               empty if the uncertainty is unknown, cannot be
#               estimated, or is not applicable (because there are no
#               coordinates). Zero is not a valid value for this term.
#
# georeferenceProtocol
#        group:
#    definedBy: http://rs.tdwg.org/dwc/terms/georeferenceProtocol
#   definition: A description or reference to the methods used to determine the
#               spatial footprint, coordinates, and uncertainties (e.g.
#               GPS, Approximated from Google Maps, Based on locality
#               name search in Google Maps (Ben Morris script) etc.)
#
# habitat
#        group:
#    definedBy: http://purl.obolibrary.org/obo/ENVO_01000739
#   definition: A category or description of the habitat in which the Event occurred.
#
# subProject
#        group: Record and Owner Details
#    definedBy: urn:subProject
#   definition: A designation of a child projecct within the larger project.
