# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/ChuBL/How-to-Use-Mindat-API/blob/main/How_to_Use_Mindat_API.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # How to Use iSamples API to Query and Download sample descriptions

# %% [markdown]
# ## 0. Access Your iSamples JWT Token

# %% [markdown]
# All of the export services are protected by authentication and require a JWT. The login URL is at [iSamples Central](https://central.isample.xyz/isamples_central/manage/login?raw_jwt=true). Make sure your orcid is allowed by talking to your iSamples in a Box administrator.
#
# Once you've obtained your JWT, you include it iAPI requests.o:

# %% [markdown]
# This set of examples runs with a web connection to the iSamples API

# %%
from pathlib import Path
import os
import sys
import json
import re
import pprint
import requests
import json
from jsonschema import validate
# import google

# %% [markdown]
# You should **avoid** placing your JWT token explicitly in your code if you plan to share it. That would include working with a notebook that is in a public Github repo, like this one.  The toke must be renewed every day.
#
# The solution here is to have the token saved in a file accessible from your notebook environment (e.g. in the same directory), and adding that file to your github .ignore file so it is not copied to the public Github repo.  This file will need to be updated daily.

# %%
jwt_file_dir = "local/jwt.txt"
try:
    with open(jwt_file_dir, 'r') as f:
        api_jwt = f.read()
except FileNotFoundError:
    print("JWT token file not found. Please create a text file containing your token and place it in the correct directory.")
    
try:
    assert 0 != len(api_jwt)
except AssertionError:
    raise Exception("Please set a JWT token before the start!")

# %% [markdown]
# ### Basic access pattern

# %%
# API root entry point
iSamples_API_baseURL = "https://central.isample.xyz/isamples_central/"

# authorization header that must be included with each request.
headers = {'Authorization': 'Bearer '+ api_jwt}
#headers

# %%
# see https://central.isample.xyz/isamples_central/docs for documentation on using the iSamples API
# get list of things https://central.isample.xyz/isamples_central/thing/?offset=0&limit=10&status=200&authority=SESAR


params = {
    'offset':'0',
    'limit':'10',
    'authority':'SESAR'
}

resource = 'thing'


# use python requests package to GET results from mindat
response = requests.get(iSamples_API_baseURL+"/" + resource + "/",
                    params=params,
                    headers=headers)
print (response.status_code)
json_array = []
json_out={}

if 200 <= response.status_code <= 299:
    json_out = response.json()
#    print (json_out)
    for anitem in json_out["data"]:
        json_array = json_array + [{"id":anitem["id"],"source":anitem["authority_id"]}]    
else:
    print ('problem-- ', response)



# this will echo the json file containing the query results.
json_array
# Out:
# 200
# [{'id': 'IGSN:ODP01WPZK', 'source': 'SESAR'},
#  {'id': 'IGSN:NHB000TLJ', 'source': 'SESAR'},
#  {'id': 'IGSN:NHB000TLL', 'source': 'SESAR'},
#  {'id': 'IGSN:NHB000TLO', 'source': 'SESAR'},
#  {'id': 'IGSN:NHB000TLR', 'source': 'SESAR'},
#  {'id': 'IGSN:NHB000TLU', 'source': 'SESAR'},
#  {'id': 'IGSN:NHB000TLX', 'source': 'SESAR'},
#  {'id': 'IGSN:NHB000TM0', 'source': 'SESAR'},
#  {'id': 'IGSN:ODP02RYR2', 'source': 'SESAR'},
#  {'id': 'IGSN:NHB000TM3', 'source': 'SESAR'}]

# %% [markdown]
# ### Get the Items with Selected Fields

# %%
f = open('../src/schemas/iSamplesSchemaCore1.0.json',) 
theschema=json.load(f)

# %% [markdown]
# # set up request for iSamples export
#
# params = {
#     'offset':'0',
#     'limit':'10',
#     'authority':'SESAR'
# }
# resource = 'thing'
#
# # use python requests package to GET results
# response = requests.get(iSamples_API_baseURL+"/" + resource + "/",
#                     params=params,
#                     headers=headers)
# print (response.status_code)

# %%
params = {
    'format':'core'
}
resource='thing'

for asample in json_array:
    print (asample["id"])
    # use python requests package to GET results
    response = requests.get(iSamples_API_baseURL+"/" + resource + "/" + asample["id"],
                    params=params,
                    headers=headers)
    print (response.status_code)
    if 200 <= response.status_code <= 299:
        json_out = response.json()
        print (json_out)
        try:
            validate(instance=json_out, schema=theschema)
        except Exception as e:
            print(e)
    else:
        print ('problem-- ', response)
# Out:
# IGSN:ODP01WPZK
# 200
# {'$schema': 'iSamplesSchemaCore1.0.json', '@id': 'https://data.isamples.org/digitalsample/igsn/ODP01WPZK', 'label': 'Sample 115-709A-17H-2 (90-92 cm.)', 'sample_identifier': 'IGSN:ODP01WPZK', 'description': '', 'has_context_category': [{'label': 'Any sampled feature', 'identifier': 'https://w3id.org/isample/vocabulary/sampledfeature/1.0/anysampledfeature'}], 'has_context_category_confidence': [1.0], 'has_material_category': [{'label': 'Natural Solid Material', 'identifier': 'https://w3id.org/isample/vocabulary/material/1.0/earthmaterial'}], 'has_material_category_confidence': [1.0], 'has_specimen_category': [{'label': 'Physical specimen', 'identifier': 'https://w3id.org/isample/vocabulary/specimentype/1.0/physicalspecimen'}], 'has_specimen_category_confidence': [1.0], 'informal_classification': [''], 'keywords': ['Individual Sample'], 'produced_by': {'@id': 'IGSN:ODP01ASA7', 'label': '', 'description': 'cruiseFieldPrgrm:ODP Leg 115. Janus sample_id: 250571', 'has_feature_of_interest': '', 'responsibility': ['Curator,,Collector', 'Curator Integrated Ocean Drilling Program (TAMU),,Sample Owner'], 'result_time': '2006-08-11 12:00:00', 'sampling_site': {'description': '', 'label': '', 'sample_location': {'elevation': '-3047.0 m', 'latitude': -3.915, 'longitude': 60.5517}, 'place_name': []}}, 'registrant': {'name': 'Curator Integrated Ocean Drilling Program (TAMU)'}, 'sampling_purpose': '', 'curation': {'label': '', 'description': '', 'access_constraints': '', 'curation_location': '', 'responsibility': []}, 'related_resource': [], 'authorized_by': [], 'complies_with': [], 'producedBy_samplingSite_location_h3_0': '8085fffffffffff', 'producedBy_samplingSite_location_h3_1': '81843ffffffffff', 'producedBy_samplingSite_location_h3_2': '828437fffffffff', 'producedBy_samplingSite_location_h3_3': '838434fffffffff', 'producedBy_samplingSite_location_h3_4': '8484341ffffffff', 'producedBy_samplingSite_location_h3_5': '8584340ffffffff', 'producedBy_samplingSite_location_h3_6': '8684340c7ffffff', 'producedBy_samplingSite_location_h3_7': '8784340c5ffffff', 'producedBy_samplingSite_location_h3_8': '8884340c57fffff', 'producedBy_samplingSite_location_h3_9': '8984340c573ffff', 'producedBy_samplingSite_location_h3_10': '8a84340c571ffff', 'producedBy_samplingSite_location_h3_11': '8b84340c571bfff', 'producedBy_samplingSite_location_h3_12': '8c84340c571bdff', 'producedBy_samplingSite_location_h3_13': '8d84340c571bd3f', 'producedBy_samplingSite_location_h3_14': '8e84340c571bd17'}
# Additional properties are not allowed ('@id' was unexpected)
#
# Failed validating 'additionalProperties' in schema['properties']['produced_by']:
#     {'additionalProperties': False,
#      'description': 'Information about the event resulting in the creation '
#                     'of the material sample. Include information about '
#                     'permitting in the authorized_by property. The '
#                     'sampling procedure should be described in the '
#                     'description. If any special protocols were followed '
#                     'in the sampling procedure, they should be documented '
#                     'using the MaterialSampleRecord/complies_with '
#                     'property.',
#      'properties': {'authorized_by': {'description': 'a list of permits or '
#                                                      'other formal '
#                                                      'permission documents '
#                                                      'under which the '
#                                                      'sample was '
#                                                      'collected. Use to '
#                                                      'cite legal documents '
#                                                      'authorizing sample '
#                                                      'collection.',
#                                       'items': {'type': 'string'},
#                                       'type': 'array'},
#                     'description': {'description': 'Free text description '
#                                                    'of the subject of a '
#                                                    'triple.',
#                                     'type': 'string'},
#                     'has_feature_of_interest': {'description': 'What does '
#                                                                'the sample '
#                                                                'represent.',
#                                                 'type': 'string'},
#                     'identifier': {'description': 'a string that '
#                                                   'identifies some '
#                                                   'resource. Expectation '
#                                                   'is that it is a URI '
#                                                   'that is resolvable to '
#                                                   'some useful '
#                                                   'represenation of the '
#                                                   'resource.',
#                                    'type': 'string'},
#                     'label': {'description': 'a human intelligible string '
#                                              'used to identify a thing, '
#                                              'i.e. the name to use for the '
#                                              'thing; should be unique in '
#                                              'the scope of a sample '
#                                              'collection or dataset.',
#                               'type': 'string'},
#                     'project': {'description': 'the name or identifier for '
#                                                'a project that is the '
#                                                'sponsor for a '
#                                                'samplingEvent. Use to link '
#                                                'samples collected in the '
#                                                'context of a particular '
#                                                'project. We do not have a '
#                                                'preferred project model at '
#                                                'this point; the RAID '
#                                                'effort (ISO23527, '
#                                                'https://www.raid.org.au/) '
#                                                'will hopefully mature into '
#                                                'a registry we can use for '
#                                                'project identification and '
#                                                'metadata. Property value '
#                                                'should be a name or a '
#                                                'resolvable URI.',
#                                 'type': 'string'},
#                     'responsibility': {'description': 'Agent object '
#                                                       'includes person '
#                                                       'name, person '
#                                                       'identifier, '
#                                                       'affiliation, or '
#                                                       'organization name, '
#                                                       'their role relative '
#                                                       'to the parent '
#                                                       'element.',
#                                        'items': {'$ref': '#/$defs/Agent'},
#                                        'type': 'array'},
#                     'result_time': {'description': 'Date on which the '
#                                                    'sample was collected.',
#                                     'format': 'date',
#                                     'type': 'string'},
#                     'sampling_site': {'$ref': '#/$defs/SamplingSite',
#                                       'description': 'object that '
#                                                      'identifies the place '
#                                                      'where the sample was '
#                                                      'collected'}},
#      'title': 'SamplingEvent',
#      'type': 'object'}
#
# On instance['produced_by']:
#     {'@id': 'IGSN:ODP01ASA7',
#      'description': 'cruiseFieldPrgrm:ODP Leg 115. Janus sample_id: 250571',
#      'has_feature_of_interest': '',
#      'label': '',
#      'responsibility': ['Curator,,Collector',
#                         'Curator Integrated Ocean Drilling Program '
#                         '(TAMU),,Sample Owner'],
#      'result_time': '2006-08-11 12:00:00',
#      'sampling_site': {'description': '',
#                        'label': '',
#                        'place_name': [],
#                        'sample_location': {'elevation': '-3047.0 m',
#                                            'latitude': -3.915,
#                                            'longitude': 60.5517}}}
# IGSN:NHB000TLJ
# 200
# {'$schema': 'iSamplesSchemaCore1.0.json', '@id': 'https://data.isamples.org/digitalsample/igsn/NHB000TLJ', 'label': 'NMNH 125875-00 (MIN)', 'sample_identifier': 'IGSN:NHB000TLJ', 'description': '', 'has_context_category': [{'label': 'Any sampled feature', 'identifier': 'https://w3id.org/isample/vocabulary/sampledfeature/1.0/anysampledfeature'}], 'has_context_category_confidence': [1.0], 'has_material_category': [{'label': 'Mineral', 'identifier': 'https://w3id.org/isample/vocabulary/material/1.0/mineral'}], 'has_material_category_confidence': None, 'has_specimen_category': [{'label': 'Physical specimen', 'identifier': 'https://w3id.org/isample/vocabulary/specimentype/1.0/physicalspecimen'}], 'has_specimen_category_confidence': [1.0], 'informal_classification': [''], 'keywords': ['Individual Sample'], 'produced_by': {'@id': '', 'label': '', 'description': '', 'has_feature_of_interest': '', 'responsibility': ['Adam Mansur,,Sample Owner'], 'result_time': '2015-05-02 11:21:17', 'sampling_site': {'description': 'Matched to Tsumeb (3352593) in GeoNames based on township and country. Assigned a 5 km error radius around the city.', 'label': '', 'sample_location': {'elevation': '', 'latitude': -19.23, 'longitude': 17.72}, 'place_name': ['Otjikoto', 'Tsumeb']}}, 'registrant': {'name': 'Adam Mansur'}, 'sampling_purpose': '', 'curation': {'label': '', 'description': '', 'access_constraints': '', 'curation_location': '', 'responsibility': []}, 'related_resource': [], 'authorized_by': [], 'complies_with': [], 'producedBy_samplingSite_location_h3_0': '80adfffffffffff', 'producedBy_samplingSite_location_h3_1': '81acbffffffffff', 'producedBy_samplingSite_location_h3_2': '82acb7fffffffff', 'producedBy_samplingSite_location_h3_3': '83acb3fffffffff', 'producedBy_samplingSite_location_h3_4': '84acb33ffffffff', 'producedBy_samplingSite_location_h3_5': '85acb32ffffffff', 'producedBy_samplingSite_location_h3_6': '86acb32e7ffffff', 'producedBy_samplingSite_location_h3_7': '87acb32e6ffffff', 'producedBy_samplingSite_location_h3_8': '88acb32e65fffff', 'producedBy_samplingSite_location_h3_9': '89acb32e643ffff', 'producedBy_samplingSite_location_h3_10': '8aacb32e640ffff', 'producedBy_samplingSite_location_h3_11': '8bacb32e6408fff', 'producedBy_samplingSite_location_h3_12': '8cacb32e64083ff', 'producedBy_samplingSite_location_h3_13': '8dacb32e64082bf', 'producedBy_samplingSite_location_h3_14': '8eacb32e640828f'}
# Additional properties are not allowed ('@id' was unexpected)
#
# Failed validating 'additionalProperties' in schema['properties']['produced_by']:
#     {'additionalProperties': False,
#      'description': 'Information about the event resulting in the creation '
#                     'of the material sample. Include information about '
#                     'permitting in the authorized_by property. The '
#                     'sampling procedure should be described in the '
#                     'description. If any special protocols were followed '
#                     'in the sampling procedure, they should be documented '
#                     'using the MaterialSampleRecord/complies_with '
#                     'property.',
#      'properties': {'authorized_by': {'description': 'a list of permits or '
#                                                      'other formal '
#                                                      'permission documents '
#                                                      'under which the '
#                                                      'sample was '
#                                                      'collected. Use to '
#                                                      'cite legal documents '
#                                                      'authorizing sample '
#                                                      'collection.',
#                                       'items': {'type': 'string'},
#                                       'type': 'array'},
#                     'description': {'description': 'Free text description '
#                                                    'of the subject of a '
#                                                    'triple.',
#                                     'type': 'string'},
#                     'has_feature_of_interest': {'description': 'What does '
#                                                                'the sample '
#                                                                'represent.',
#                                                 'type': 'string'},
#                     'identifier': {'description': 'a string that '
#                                                   'identifies some '
#                                                   'resource. Expectation '
#                                                   'is that it is a URI '
#                                                   'that is resolvable to '
#                                                   'some useful '
#                                                   'represenation of the '
#                                                   'resource.',
#                                    'type': 'string'},
#                     'label': {'description': 'a human intelligible string '
#                                              'used to identify a thing, '
#                                              'i.e. the name to use for the '
#                                              'thing; should be unique in '
#                                              'the scope of a sample '
#                                              'collection or dataset.',
#                               'type': 'string'},
#                     'project': {'description': 'the name or identifier for '
#                                                'a project that is the '
#                                                'sponsor for a '
#                                                'samplingEvent. Use to link '
#                                                'samples collected in the '
#                                                'context of a particular '
#                                                'project. We do not have a '
#                                                'preferred project model at '
#                                                'this point; the RAID '
#                                                'effort (ISO23527, '
#                                                'https://www.raid.org.au/) '
#                                                'will hopefully mature into '
#                                                'a registry we can use for '
#                                                'project identification and '
#                                                'metadata. Property value '
#                                                'should be a name or a '
#                                                'resolvable URI.',
#                                 'type': 'string'},
#                     'responsibility': {'description': 'Agent object '
#                                                       'includes person '
#                                                       'name, person '
#                                                       'identifier, '
#                                                       'affiliation, or '
#                                                       'organization name, '
#                                                       'their role relative '
#                                                       'to the parent '
#                                                       'element.',
#                                        'items': {'$ref': '#/$defs/Agent'},
#                                        'type': 'array'},
#                     'result_time': {'description': 'Date on which the '
#                                                    'sample was collected.',
#                                     'format': 'date',
#                                     'type': 'string'},
#                     'sampling_site': {'$ref': '#/$defs/SamplingSite',
#                                       'description': 'object that '
#                                                      'identifies the place '
#                                                      'where the sample was '
#                                                      'collected'}},
#      'title': 'SamplingEvent',
#      'type': 'object'}
#
# On instance['produced_by']:
#     {'@id': '',
#      'description': '',
#      'has_feature_of_interest': '',
#      'label': '',
#      'responsibility': ['Adam Mansur,,Sample Owner'],
#      'result_time': '2015-05-02 11:21:17',
#      'sampling_site': {'description': 'Matched to Tsumeb (3352593) in '
#                                       'GeoNames based on township and '
#                                       'country. Assigned a 5 km error '
#                                       'radius around the city.',
#                        'label': '',
#                        'place_name': ['Otjikoto', 'Tsumeb'],
#                        'sample_location': {'elevation': '',
#                                            'latitude': -19.23,
#                                            'longitude': 17.72}}}
# IGSN:NHB000TLL
# 200
# {'$schema': 'iSamplesSchemaCore1.0.json', '@id': 'https://data.isamples.org/digitalsample/igsn/NHB000TLL', 'label': 'NMNH 125878-00 (MIN)', 'sample_identifier': 'IGSN:NHB000TLL', 'description': '', 'has_context_category': [{'label': 'Any sampled feature', 'identifier': 'https://w3id.org/isample/vocabulary/sampledfeature/1.0/anysampledfeature'}], 'has_context_category_confidence': [1.0], 'has_material_category': [{'label': 'Mineral', 'identifier': 'https://w3id.org/isample/vocabulary/material/1.0/mineral'}], 'has_material_category_confidence': None, 'has_specimen_category': [{'label': 'Physical specimen', 'identifier': 'https://w3id.org/isample/vocabulary/specimentype/1.0/physicalspecimen'}], 'has_specimen_category_confidence': [1.0], 'informal_classification': [''], 'keywords': ['Individual Sample'], 'produced_by': {'@id': '', 'label': '', 'description': '', 'has_feature_of_interest': '', 'responsibility': ['Adam Mansur,,Sample Owner'], 'result_time': '2015-05-02 11:21:26', 'sampling_site': {'description': 'Matched to the GeoNames record for Pima Co., Arizona, United States (http://geonames.org/5308878) based on district/county name, state/province, and country using the situate.py script. Other place names mentioned in the EMu record ("Santa Rita Mtns." and Cave Of The Swords) could not be matched and were ignored when determining the coordinates given here. Bounding box coordinates were rounded to 2 decimal places from the values given by GeoNames. The uncertainty radius represents the center-to-corner distance of the bounding box (149 km).', 'label': '', 'sample_location': {'elevation': '', 'latitude': 31.97, 'longitude': -111.89}, 'place_name': ['Arizona', 'Pima Co.']}}, 'registrant': {'name': 'Adam Mansur'}, 'sampling_purpose': '', 'curation': {'label': '', 'description': '', 'access_constraints': '', 'curation_location': '', 'responsibility': []}, 'related_resource': [], 'authorized_by': [], 'complies_with': [], 'producedBy_samplingSite_location_h3_0': '8049fffffffffff', 'producedBy_samplingSite_location_h3_1': '8148fffffffffff', 'producedBy_samplingSite_location_h3_2': '8248effffffffff', 'producedBy_samplingSite_location_h3_3': '8348e8fffffffff', 'producedBy_samplingSite_location_h3_4': '8448e8bffffffff', 'producedBy_samplingSite_location_h3_5': '8548e8b3fffffff', 'producedBy_samplingSite_location_h3_6': '8648e8b2fffffff', 'producedBy_samplingSite_location_h3_7': '8748e8b2cffffff', 'producedBy_samplingSite_location_h3_8': '8848e8b2c9fffff', 'producedBy_samplingSite_location_h3_9': '8948e8b2c8bffff', 'producedBy_samplingSite_location_h3_10': '8a48e8b2c88ffff', 'producedBy_samplingSite_location_h3_11': '8b48e8b2c88afff', 'producedBy_samplingSite_location_h3_12': '8c48e8b2c88abff', 'producedBy_samplingSite_location_h3_13': '8d48e8b2c88ab7f', 'producedBy_samplingSite_location_h3_14': '8e48e8b2c88ab0f'}
# Additional properties are not allowed ('@id' was unexpected)
#
# Failed validating 'additionalProperties' in schema['properties']['produced_by']:
#     {'additionalProperties': False,
#      'description': 'Information about the event resulting in the creation '
#                     'of the material sample. Include information about '
#                     'permitting in the authorized_by property. The '
#                     'sampling procedure should be described in the '
#                     'description. If any special protocols were followed '
#                     'in the sampling procedure, they should be documented '
#                     'using the MaterialSampleRecord/complies_with '
#                     'property.',
#      'properties': {'authorized_by': {'description': 'a list of permits or '
#                                                      'other formal '
#                                                      'permission documents '
#                                                      'under which the '
#                                                      'sample was '
#                                                      'collected. Use to '
#                                                      'cite legal documents '
#                                                      'authorizing sample '
#                                                      'collection.',
#                                       'items': {'type': 'string'},
#                                       'type': 'array'},
#                     'description': {'description': 'Free text description '
#                                                    'of the subject of a '
#                                                    'triple.',
#                                     'type': 'string'},
#                     'has_feature_of_interest': {'description': 'What does '
#                                                                'the sample '
#                                                                'represent.',
#                                                 'type': 'string'},
#                     'identifier': {'description': 'a string that '
#                                                   'identifies some '
#                                                   'resource. Expectation '
#                                                   'is that it is a URI '
#                                                   'that is resolvable to '
#                                                   'some useful '
#                                                   'represenation of the '
#                                                   'resource.',
#                                    'type': 'string'},
#                     'label': {'description': 'a human intelligible string '
#                                              'used to identify a thing, '
#                                              'i.e. the name to use for the '
#                                              'thing; should be unique in '
#                                              'the scope of a sample '
#                                              'collection or dataset.',
#                               'type': 'string'},
#                     'project': {'description': 'the name or identifier for '
#                                                'a project that is the '
#                                                'sponsor for a '
#                                                'samplingEvent. Use to link '
#                                                'samples collected in the '
#                                                'context of a particular '
#                                                'project. We do not have a '
#                                                'preferred project model at '
#                                                'this point; the RAID '
#                                                'effort (ISO23527, '
#                                                'https://www.raid.org.au/) '
#                                                'will hopefully mature into '
#                                                'a registry we can use for '
#                                                'project identification and '
#                                                'metadata. Property value '
#                                                'should be a name or a '
#                                                'resolvable URI.',
#                                 'type': 'string'},
#                     'responsibility': {'description': 'Agent object '
#                                                       'includes person '
#                                                       'name, person '
#                                                       'identifier, '
#                                                       'affiliation, or '
#                                                       'organization name, '
#                                                       'their role relative '
#                                                       'to the parent '
#                                                       'element.',
#                                        'items': {'$ref': '#/$defs/Agent'},
#                                        'type': 'array'},
#                     'result_time': {'description': 'Date on which the '
#                                                    'sample was collected.',
#                                     'format': 'date',
#                                     'type': 'string'},
#                     'sampling_site': {'$ref': '#/$defs/SamplingSite',
#                                       'description': 'object that '
#                                                      'identifies the place '
#                                                      'where the sample was '
#                                                      'collected'}},
#      'title': 'SamplingEvent',
#      'type': 'object'}
#
# On instance['produced_by']:
#     {'@id': '',
#      'description': '',
#      'has_feature_of_interest': '',
#      'label': '',
#      'responsibility': ['Adam Mansur,,Sample Owner'],
#      'result_time': '2015-05-02 11:21:26',
#      'sampling_site': {'description': 'Matched to the GeoNames record for '
#                                       'Pima Co., Arizona, United States '
#                                       '(http://geonames.org/5308878) based '
#                                       'on district/county name, '
#                                       'state/province, and country using '
#                                       'the situate.py script. Other place '
#                                       'names mentioned in the EMu record '
#                                       '("Santa Rita Mtns." and Cave Of The '
#                                       'Swords) could not be matched and '
#                                       'were ignored when determining the '
#                                       'coordinates given here. Bounding '
#                                       'box coordinates were rounded to 2 '
#                                       'decimal places from the values '
#                                       'given by GeoNames. The uncertainty '
#                                       'radius represents the '
#                                       'center-to-corner distance of the '
#                                       'bounding box (149 km).',
#                        'label': '',
#                        'place_name': ['Arizona', 'Pima Co.'],
#                        'sample_location': {'elevation': '',
#                                            'latitude': 31.97,
#                                            'longitude': -111.89}}}
# IGSN:NHB000TLO
# 200
# {'$schema': 'iSamplesSchemaCore1.0.json', '@id': 'https://data.isamples.org/digitalsample/igsn/NHB000TLO', 'label': 'NMNH 125881-00 (MIN)', 'sample_identifier': 'IGSN:NHB000TLO', 'description': '', 'has_context_category': [{'label': 'Any sampled feature', 'identifier': 'https://w3id.org/isample/vocabulary/sampledfeature/1.0/anysampledfeature'}], 'has_context_category_confidence': [1.0], 'has_material_category': [{'label': 'Mineral', 'identifier': 'https://w3id.org/isample/vocabulary/material/1.0/mineral'}], 'has_material_category_confidence': None, 'has_specimen_category': [{'label': 'Physical specimen', 'identifier': 'https://w3id.org/isample/vocabulary/specimentype/1.0/physicalspecimen'}], 'has_specimen_category_confidence': [1.0], 'informal_classification': [''], 'keywords': ['Individual Sample'], 'produced_by': {'@id': '', 'label': '', 'description': '', 'has_feature_of_interest': '', 'responsibility': ['Adam Mansur,,Sample Owner'], 'result_time': '2015-05-02 11:21:42', 'sampling_site': {'description': 'Matched to the GeoNames record for Concepción del Oro, Zacatecas, Mexico (http://geonames.org/8583968) based on feature name, state/province, and country using the situate.py script. The script determined that the two sites that best match the information in this record are related and kept the less specific one (featureCode=ADM2). This was the most specific match possible based on information available in this record. Bounding box coordinates were rounded to 2 decimal places from the values given by GeoNames. The error radius represents the center-to-corner distance of the bounding box.', 'label': '', 'sample_location': {'elevation': '', 'latitude': 24.45, 'longitude': -101.23}, 'place_name': ['Zacatecas']}}, 'registrant': {'name': 'Adam Mansur'}, 'sampling_purpose': '', 'curation': {'label': '', 'description': '', 'access_constraints': '', 'curation_location': '', 'responsibility': []}, 'related_resource': [], 'authorized_by': [], 'complies_with': [], 'producedBy_samplingSite_location_h3_0': '8049fffffffffff', 'producedBy_samplingSite_location_h3_1': '8148bffffffffff', 'producedBy_samplingSite_location_h3_2': '8248a7fffffffff', 'producedBy_samplingSite_location_h3_3': '8348a4fffffffff', 'producedBy_samplingSite_location_h3_4': '8448a47ffffffff', 'producedBy_samplingSite_location_h3_5': '8548a46bfffffff', 'producedBy_samplingSite_location_h3_6': '8648a46afffffff', 'producedBy_samplingSite_location_h3_7': '8748a46a8ffffff', 'producedBy_samplingSite_location_h3_8': '8848a46a81fffff', 'producedBy_samplingSite_location_h3_9': '8948a46a80bffff', 'producedBy_samplingSite_location_h3_10': '8a48a46a819ffff', 'producedBy_samplingSite_location_h3_11': '8b48a46a80a6fff', 'producedBy_samplingSite_location_h3_12': '8c48a46a80a6dff', 'producedBy_samplingSite_location_h3_13': '8d48a46a80a6d3f', 'producedBy_samplingSite_location_h3_14': '8e48a46a80a6d17'}
# Additional properties are not allowed ('@id' was unexpected)
#
# Failed validating 'additionalProperties' in schema['properties']['produced_by']:
#     {'additionalProperties': False,
#      'description': 'Information about the event resulting in the creation '
#                     'of the material sample. Include information about '
#                     'permitting in the authorized_by property. The '
#                     'sampling procedure should be described in the '
#                     'description. If any special protocols were followed '
#                     'in the sampling procedure, they should be documented '
#                     'using the MaterialSampleRecord/complies_with '
#                     'property.',
#      'properties': {'authorized_by': {'description': 'a list of permits or '
#                                                      'other formal '
#                                                      'permission documents '
#                                                      'under which the '
#                                                      'sample was '
#                                                      'collected. Use to '
#                                                      'cite legal documents '
#                                                      'authorizing sample '
#                                                      'collection.',
#                                       'items': {'type': 'string'},
#                                       'type': 'array'},
#                     'description': {'description': 'Free text description '
#                                                    'of the subject of a '
#                                                    'triple.',
#                                     'type': 'string'},
#                     'has_feature_of_interest': {'description': 'What does '
#                                                                'the sample '
#                                                                'represent.',
#                                                 'type': 'string'},
#                     'identifier': {'description': 'a string that '
#                                                   'identifies some '
#                                                   'resource. Expectation '
#                                                   'is that it is a URI '
#                                                   'that is resolvable to '
#                                                   'some useful '
#                                                   'represenation of the '
#                                                   'resource.',
#                                    'type': 'string'},
#                     'label': {'description': 'a human intelligible string '
#                                              'used to identify a thing, '
#                                              'i.e. the name to use for the '
#                                              'thing; should be unique in '
#                                              'the scope of a sample '
#                                              'collection or dataset.',
#                               'type': 'string'},
#                     'project': {'description': 'the name or identifier for '
#                                                'a project that is the '
#                                                'sponsor for a '
#                                                'samplingEvent. Use to link '
#                                                'samples collected in the '
#                                                'context of a particular '
#                                                'project. We do not have a '
#                                                'preferred project model at '
#                                                'this point; the RAID '
#                                                'effort (ISO23527, '
#                                                'https://www.raid.org.au/) '
#                                                'will hopefully mature into '
#                                                'a registry we can use for '
#                                                'project identification and '
#                                                'metadata. Property value '
#                                                'should be a name or a '
#                                                'resolvable URI.',
#                                 'type': 'string'},
#                     'responsibility': {'description': 'Agent object '
#                                                       'includes person '
#                                                       'name, person '
#                                                       'identifier, '
#                                                       'affiliation, or '
#                                                       'organization name, '
#                                                       'their role relative '
#                                                       'to the parent '
#                                                       'element.',
#                                        'items': {'$ref': '#/$defs/Agent'},
#                                        'type': 'array'},
#                     'result_time': {'description': 'Date on which the '
#                                                    'sample was collected.',
#                                     'format': 'date',
#                                     'type': 'string'},
#                     'sampling_site': {'$ref': '#/$defs/SamplingSite',
#                                       'description': 'object that '
#                                                      'identifies the place '
#                                                      'where the sample was '
#                                                      'collected'}},
#      'title': 'SamplingEvent',
#      'type': 'object'}
#
# On instance['produced_by']:
#     {'@id': '',
#      'description': '',
#      'has_feature_of_interest': '',
#      'label': '',
#      'responsibility': ['Adam Mansur,,Sample Owner'],
#      'result_time': '2015-05-02 11:21:42',
#      'sampling_site': {'description': 'Matched to the GeoNames record for '
#                                       'Concepción del Oro, Zacatecas, '
#                                       'Mexico '
#                                       '(http://geonames.org/8583968) based '
#                                       'on feature name, state/province, '
#                                       'and country using the situate.py '
#                                       'script. The script determined that '
#                                       'the two sites that best match the '
#                                       'information in this record are '
#                                       'related and kept the less specific '
#                                       'one (featureCode=ADM2). This was '
#                                       'the most specific match possible '
#                                       'based on information available in '
#                                       'this record. Bounding box '
#                                       'coordinates were rounded to 2 '
#                                       'decimal places from the values '
#                                       'given by GeoNames. The error radius '
#                                       'represents the center-to-corner '
#                                       'distance of the bounding box.',
#                        'label': '',
#                        'place_name': ['Zacatecas'],
#                        'sample_location': {'elevation': '',
#                                            'latitude': 24.45,
#                                            'longitude': -101.23}}}
# IGSN:NHB000TLR
# 200
# {'$schema': 'iSamplesSchemaCore1.0.json', '@id': 'https://data.isamples.org/digitalsample/igsn/NHB000TLR', 'label': 'NMNH 125884-00 (MIN)', 'sample_identifier': 'IGSN:NHB000TLR', 'description': '', 'has_context_category': [{'label': 'Any sampled feature', 'identifier': 'https://w3id.org/isample/vocabulary/sampledfeature/1.0/anysampledfeature'}], 'has_context_category_confidence': [1.0], 'has_material_category': [{'label': 'Mineral', 'identifier': 'https://w3id.org/isample/vocabulary/material/1.0/mineral'}], 'has_material_category_confidence': None, 'has_specimen_category': [{'label': 'Physical specimen', 'identifier': 'https://w3id.org/isample/vocabulary/specimentype/1.0/physicalspecimen'}], 'has_specimen_category_confidence': [1.0], 'informal_classification': [''], 'keywords': ['Individual Sample'], 'produced_by': {'@id': '', 'label': '', 'description': '', 'has_feature_of_interest': '', 'responsibility': ['Adam Mansur,,Sample Owner'], 'result_time': '2015-05-02 11:21:58', 'sampling_site': {'description': 'Matched to the GeoNames record for Treasury Tunnel, Ouray Co., Colorado, United States (http://geonames.org/5441951) based on feature name, district/county, state/province, and country using the situate.py script. The script determined that Treasury Tunnel (featureCode=MN) is located within Ouray (featureCode=ADM2), another feature mentioned in this record. This was the most specific match possible based on information available in this record. Point coordinates were rounded to 2 decimal places from the values given by GeoNames. An arbitrary error radius of 1 km was assigned to all featureCode=MN records matched using the script.', 'label': '', 'sample_location': {'elevation': '', 'latitude': 37.91, 'longitude': -107.7}, 'place_name': ['Colorado', 'Ouray Co.']}}, 'registrant': {'name': 'Adam Mansur'}, 'sampling_purpose': '', 'curation': {'label': '', 'description': '', 'access_constraints': '', 'curation_location': '', 'responsibility': []}, 'related_resource': [], 'authorized_by': [], 'complies_with': [], 'producedBy_samplingSite_location_h3_0': '8027fffffffffff', 'producedBy_samplingSite_location_h3_1': '8126bffffffffff', 'producedBy_samplingSite_location_h3_2': '82269ffffffffff', 'producedBy_samplingSite_location_h3_3': '83269dfffffffff', 'producedBy_samplingSite_location_h3_4': '842698bffffffff', 'producedBy_samplingSite_location_h3_5': '85269d6bfffffff', 'producedBy_samplingSite_location_h3_6': '86269d697ffffff', 'producedBy_samplingSite_location_h3_7': '87269d696ffffff', 'producedBy_samplingSite_location_h3_8': '88269d696bfffff', 'producedBy_samplingSite_location_h3_9': '89269d696b3ffff', 'producedBy_samplingSite_location_h3_10': '8a269d696b0ffff', 'producedBy_samplingSite_location_h3_11': '8b269d696b09fff', 'producedBy_samplingSite_location_h3_12': '8c269d696b097ff', 'producedBy_samplingSite_location_h3_13': '8d269d696b097bf', 'producedBy_samplingSite_location_h3_14': '8e269d696b097af'}
# Additional properties are not allowed ('@id' was unexpected)
#
# Failed validating 'additionalProperties' in schema['properties']['produced_by']:
#     {'additionalProperties': False,
#      'description': 'Information about the event resulting in the creation '
#                     'of the material sample. Include information about '
#                     'permitting in the authorized_by property. The '
#                     'sampling procedure should be described in the '
#                     'description. If any special protocols were followed '
#                     'in the sampling procedure, they should be documented '
#                     'using the MaterialSampleRecord/complies_with '
#                     'property.',
#      'properties': {'authorized_by': {'description': 'a list of permits or '
#                                                      'other formal '
#                                                      'permission documents '
#                                                      'under which the '
#                                                      'sample was '
#                                                      'collected. Use to '
#                                                      'cite legal documents '
#                                                      'authorizing sample '
#                                                      'collection.',
#                                       'items': {'type': 'string'},
#                                       'type': 'array'},
#                     'description': {'description': 'Free text description '
#                                                    'of the subject of a '
#                                                    'triple.',
#                                     'type': 'string'},
#                     'has_feature_of_interest': {'description': 'What does '
#                                                                'the sample '
#                                                                'represent.',
#                                                 'type': 'string'},
#                     'identifier': {'description': 'a string that '
#                                                   'identifies some '
#                                                   'resource. Expectation '
#                                                   'is that it is a URI '
#                                                   'that is resolvable to '
#                                                   'some useful '
#                                                   'represenation of the '
#                                                   'resource.',
#                                    'type': 'string'},
#                     'label': {'description': 'a human intelligible string '
#                                              'used to identify a thing, '
#                                              'i.e. the name to use for the '
#                                              'thing; should be unique in '
#                                              'the scope of a sample '
#                                              'collection or dataset.',
#                               'type': 'string'},
#                     'project': {'description': 'the name or identifier for '
#                                                'a project that is the '
#                                                'sponsor for a '
#                                                'samplingEvent. Use to link '
#                                                'samples collected in the '
#                                                'context of a particular '
#                                                'project. We do not have a '
#                                                'preferred project model at '
#                                                'this point; the RAID '
#                                                'effort (ISO23527, '
#                                                'https://www.raid.org.au/) '
#                                                'will hopefully mature into '
#                                                'a registry we can use for '
#                                                'project identification and '
#                                                'metadata. Property value '
#                                                'should be a name or a '
#                                                'resolvable URI.',
#                                 'type': 'string'},
#                     'responsibility': {'description': 'Agent object '
#                                                       'includes person '
#                                                       'name, person '
#                                                       'identifier, '
#                                                       'affiliation, or '
#                                                       'organization name, '
#                                                       'their role relative '
#                                                       'to the parent '
#                                                       'element.',
#                                        'items': {'$ref': '#/$defs/Agent'},
#                                        'type': 'array'},
#                     'result_time': {'description': 'Date on which the '
#                                                    'sample was collected.',
#                                     'format': 'date',
# ...
#                                                      'under which the '
#                                                      'sample was '
#                                                      'collected. Use to '
#                                                      'cite legal documents '
#                                                      'authorizing sample '
#                                                      'collection.',
#                                       'items': {'type': 'string'},
#                                       'type': 'array'},
#                     'description': {'description': 'Free text description '
#                                                    'of the subject of a '
#                                                    'triple.',
#                                     'type': 'string'},
#                     'has_feature_of_interest': {'description': 'What does '
#                                                                'the sample '
#                                                                'represent.',
#                                                 'type': 'string'},
#                     'identifier': {'description': 'a string that '
#                                                   'identifies some '
#                                                   'resource. Expectation '
#                                                   'is that it is a URI '
#                                                   'that is resolvable to '
#                                                   'some useful '
#                                                   'represenation of the '
#                                                   'resource.',
#                                    'type': 'string'},
#                     'label': {'description': 'a human intelligible string '
#                                              'used to identify a thing, '
#                                              'i.e. the name to use for the '
#                                              'thing; should be unique in '
#                                              'the scope of a sample '
#                                              'collection or dataset.',
#                               'type': 'string'},
#                     'project': {'description': 'the name or identifier for '
#                                                'a project that is the '
#                                                'sponsor for a '
#                                                'samplingEvent. Use to link '
#                                                'samples collected in the '
#                                                'context of a particular '
#                                                'project. We do not have a '
#                                                'preferred project model at '
#                                                'this point; the RAID '
#                                                'effort (ISO23527, '
#                                                'https://www.raid.org.au/) '
#                                                'will hopefully mature into '
#                                                'a registry we can use for '
#                                                'project identification and '
#                                                'metadata. Property value '
#                                                'should be a name or a '
#                                                'resolvable URI.',
#                                 'type': 'string'},
#                     'responsibility': {'description': 'Agent object '
#                                                       'includes person '
#                                                       'name, person '
#                                                       'identifier, '
#                                                       'affiliation, or '
#                                                       'organization name, '
#                                                       'their role relative '
#                                                       'to the parent '
#                                                       'element.',
#                                        'items': {'$ref': '#/$defs/Agent'},
#                                        'type': 'array'},
#                     'result_time': {'description': 'Date on which the '
#                                                    'sample was collected.',
#                                     'format': 'date',
#                                     'type': 'string'},
#                     'sampling_site': {'$ref': '#/$defs/SamplingSite',
#                                       'description': 'object that '
#                                                      'identifies the place '
#                                                      'where the sample was '
#                                                      'collected'}},
#      'title': 'SamplingEvent',
#      'type': 'object'}
#
# On instance['produced_by']:
#     {'@id': 'IGSN:ODP01M593',
#      'description': 'cruiseFieldPrgrm:ODP Leg 183. Janus sample_id: '
#                     '1307325',
#      'has_feature_of_interest': '',
#      'label': '',
#      'responsibility': ['Curator,,Collector',
#                         'Curator Integrated Ocean Drilling Program '
#                         '(TAMU),,Sample Owner'],
#      'result_time': '2006-08-11 12:00:00',
#      'sampling_site': {'description': '',
#                        'label': '',
#                        'place_name': [],
#                        'sample_location': {'elevation': '-1415.3 m',
#                                            'latitude': -50.18505,
#                                            'longitude': 63.93653}}}
# IGSN:NHB000TM3
# 200
# {'$schema': 'iSamplesSchemaCore1.0.json', '@id': 'https://data.isamples.org/digitalsample/igsn/NHB000TM3', 'label': 'NMNH 125896-00 (MIN)', 'sample_identifier': 'IGSN:NHB000TM3', 'description': '', 'has_context_category': [{'label': 'Any sampled feature', 'identifier': 'https://w3id.org/isample/vocabulary/sampledfeature/1.0/anysampledfeature'}], 'has_context_category_confidence': [1.0], 'has_material_category': [{'label': 'Mineral', 'identifier': 'https://w3id.org/isample/vocabulary/material/1.0/mineral'}], 'has_material_category_confidence': None, 'has_specimen_category': [{'label': 'Physical specimen', 'identifier': 'https://w3id.org/isample/vocabulary/specimentype/1.0/physicalspecimen'}], 'has_specimen_category_confidence': [1.0], 'informal_classification': [''], 'keywords': ['Individual Sample'], 'produced_by': {'@id': '', 'label': '', 'description': '', 'has_feature_of_interest': '', 'responsibility': ['Adam Mansur,,Sample Owner'], 'result_time': '2015-05-02 11:22:58', 'sampling_site': {'description': 'Multiple records from GeoNames matched the locality Charcas, Charcas, San Luis Potosí, Mexico, including http://geonames.org/4014498, http://geonames.org/4014501, and http://geonames.org/8583304. The situate.py script was unable to distinguish between these localities, and the coordinates and error radius given here describe a circle encompassing all 3 localities. This was the most specific place name found in this record.', 'label': '', 'sample_location': {'elevation': '', 'latitude': 23.14, 'longitude': -101.09}, 'place_name': ['San Luis Potosí']}}, 'registrant': {'name': 'Adam Mansur'}, 'sampling_purpose': '', 'curation': {'label': '', 'description': '', 'access_constraints': '', 'curation_location': '', 'responsibility': []}, 'related_resource': [], 'authorized_by': [], 'complies_with': [], 'producedBy_samplingSite_location_h3_0': '8049fffffffffff', 'producedBy_samplingSite_location_h3_1': '8149bffffffffff', 'producedBy_samplingSite_location_h3_2': '82499ffffffffff', 'producedBy_samplingSite_location_h3_3': '834999fffffffff', 'producedBy_samplingSite_location_h3_4': '844999bffffffff', 'producedBy_samplingSite_location_h3_5': '854999b7fffffff', 'producedBy_samplingSite_location_h3_6': '864999b77ffffff', 'producedBy_samplingSite_location_h3_7': '874999b72ffffff', 'producedBy_samplingSite_location_h3_8': '884999b72dfffff', 'producedBy_samplingSite_location_h3_9': '894999b72c3ffff', 'producedBy_samplingSite_location_h3_10': '8a4999b72c77fff', 'producedBy_samplingSite_location_h3_11': '8b4999b72c76fff', 'producedBy_samplingSite_location_h3_12': '8c4999b72c769ff', 'producedBy_samplingSite_location_h3_13': '8d4999b72c769bf', 'producedBy_samplingSite_location_h3_14': '8e4999b72c769b7'}
# Additional properties are not allowed ('@id' was unexpected)
#
# Failed validating 'additionalProperties' in schema['properties']['produced_by']:
#     {'additionalProperties': False,
#      'description': 'Information about the event resulting in the creation '
#                     'of the material sample. Include information about '
#                     'permitting in the authorized_by property. The '
#                     'sampling procedure should be described in the '
#                     'description. If any special protocols were followed '
#                     'in the sampling procedure, they should be documented '
#                     'using the MaterialSampleRecord/complies_with '
#                     'property.',
#      'properties': {'authorized_by': {'description': 'a list of permits or '
#                                                      'other formal '
#                                                      'permission documents '
#                                                      'under which the '
#                                                      'sample was '
#                                                      'collected. Use to '
#                                                      'cite legal documents '
#                                                      'authorizing sample '
#                                                      'collection.',
#                                       'items': {'type': 'string'},
#                                       'type': 'array'},
#                     'description': {'description': 'Free text description '
#                                                    'of the subject of a '
#                                                    'triple.',
#                                     'type': 'string'},
#                     'has_feature_of_interest': {'description': 'What does '
#                                                                'the sample '
#                                                                'represent.',
#                                                 'type': 'string'},
#                     'identifier': {'description': 'a string that '
#                                                   'identifies some '
#                                                   'resource. Expectation '
#                                                   'is that it is a URI '
#                                                   'that is resolvable to '
#                                                   'some useful '
#                                                   'represenation of the '
#                                                   'resource.',
#                                    'type': 'string'},
#                     'label': {'description': 'a human intelligible string '
#                                              'used to identify a thing, '
#                                              'i.e. the name to use for the '
#                                              'thing; should be unique in '
#                                              'the scope of a sample '
#                                              'collection or dataset.',
#                               'type': 'string'},
#                     'project': {'description': 'the name or identifier for '
#                                                'a project that is the '
#                                                'sponsor for a '
#                                                'samplingEvent. Use to link '
#                                                'samples collected in the '
#                                                'context of a particular '
#                                                'project. We do not have a '
#                                                'preferred project model at '
#                                                'this point; the RAID '
#                                                'effort (ISO23527, '
#                                                'https://www.raid.org.au/) '
#                                                'will hopefully mature into '
#                                                'a registry we can use for '
#                                                'project identification and '
#                                                'metadata. Property value '
#                                                'should be a name or a '
#                                                'resolvable URI.',
#                                 'type': 'string'},
#                     'responsibility': {'description': 'Agent object '
#                                                       'includes person '
#                                                       'name, person '
#                                                       'identifier, '
#                                                       'affiliation, or '
#                                                       'organization name, '
#                                                       'their role relative '
#                                                       'to the parent '
#                                                       'element.',
#                                        'items': {'$ref': '#/$defs/Agent'},
#                                        'type': 'array'},
#                     'result_time': {'description': 'Date on which the '
#                                                    'sample was collected.',
#                                     'format': 'date',
#                                     'type': 'string'},
#                     'sampling_site': {'$ref': '#/$defs/SamplingSite',
#                                       'description': 'object that '
#                                                      'identifies the place '
#                                                      'where the sample was '
#                                                      'collected'}},
#      'title': 'SamplingEvent',
#      'type': 'object'}
#
# On instance['produced_by']:
#     {'@id': '',
#      'description': '',
#      'has_feature_of_interest': '',
#      'label': '',
#      'responsibility': ['Adam Mansur,,Sample Owner'],
#      'result_time': '2015-05-02 11:22:58',
#      'sampling_site': {'description': 'Multiple records from GeoNames '
#                                       'matched the locality Charcas, '
#                                       'Charcas, San Luis Potosí, Mexico, '
#                                       'including '
#                                       'http://geonames.org/4014498, '
#                                       'http://geonames.org/4014501, and '
#                                       'http://geonames.org/8583304. The '
#                                       'situate.py script was unable to '
#                                       'distinguish between these '
#                                       'localities, and the coordinates and '
#                                       'error radius given here describe a '
#                                       'circle encompassing all 3 '
#                                       'localities. This was the most '
#                                       'specific place name found in this '
#                                       'record.',
#                        'label': '',
#                        'place_name': ['San Luis Potosí'],
#                        'sample_location': {'elevation': '',
#                                            'latitude': 23.14,
#                                            'longitude': -101.09}}}

# %% [markdown]
# get count of localities

# %%
import pandas
import time

idlist=[]
fields_str = 'id','name', 'locality','longid','groupid'
#, 'name', 'locality','longid','groupid'

json_array = []
json_array2 = []
json_out={}
summary={}
#        'id__in': idstr,
#    'expand':'locality'
for agroup in grouplist:
    params = {
        'fields': fields_str, # put your selected fields here
        'format': 'json',
        'groupid': agroup,
        'page_size': 1000
    }
    #params = {}
    response = requests.get(MINDAT_API_URL+"/geomaterials/",
                params=params,
                headers=headers)
    print (response.status_code)
    
    if 200 <= response.status_code <= 299:
        json_out = response.json()
        print (json_out)
        idlist2=[]
        for anitem in json_out["results"]:
            idlist2=idlist2+[str(anitem["id"])]
       #     summary={"results":[{"id":anitem["id"], "name":anitem["name"], "count":len(anitem["locality"])}]}
       #     #print(summary)
        #    json_array = json_array + [{"id":anitem["id"], "name":anitem["name"], "count":len(anitem["locality"])}]
    else:
        print ('problem-- ', params["id__in"])
    
    fields_str2 = 'id', 'name', 'locality','longid'
    count = 0
    localities=[]
    for idstr in idlist2:
        params = {
            'fields': fields_str2, # put your selected fields here
            'id__in': idstr, # set the item amount for each page
            'format': 'json',
            'expand':'locality'
        }
        response = requests.get(MINDAT_API_URL+"/geomaterials/",
                        params=params,
                        headers=headers)
        if 200 <= response.status_code <= 299:
            json_out = response.json()
            #print (json_out)
            for anitem in json_out["results"]:
                localities = localities + anitem["locality"]
                print(anitem["name"], 'count:', len(anitem["locality"]))
        else:
            print ('problem-- ', idstr)
    
    localities=list(set(localities))  #remove duplicates
    count=len(localities)
    print('group:',agroup,', count:',count)
    json_array = json_array + [{"group":agroup, "count":count}]
    time.sleep(2)

print ('Done')  

json_array
#json_array2
df_result = pandas.DataFrame(json_array)
df_result.to_csv('GroupCountDrillDown.csv')

# %% [raw]
# while json_out["next"] is not None :
#     response = requests.get(json_out["next"],
#                 params=params,
#                 headers=headers)
#
#     print (response.status_code)
#     if 200 <= response.status_code <= 299:
#         json_out = response.json()
#         print (json_out)
#         json_array = json_array + json_out["results"]
#     else:
#         print ('problem-- ', json_out["next"])
#
#     time.sleep(3)

# %% [markdown]
# query for items by id in an id list

# %%
import pandas
import time

json_array = []
fields_str2 = 'id', 'name', 'locality','longid', 'groupid'

idlist = ['8598']

for idstr in idlist:

    params = {
        'fields': fields_str, # put your selected fields here
        'id__in': idstr, # set the item amount for each page
        'format': 'json',
        'expand':'locality'
    }

    response = requests.get(MINDAT_API_URL+"/geomaterials/",
                    params=params,
                    headers=headers)

    if 200 <= response.status_code <= 299:
        json_out = response.json()
        #print (json_out)
        json_array = json_array + json_out["results"]
    else:
        print ('problem-- ', idstr)
 
    time.sleep(3)
    
    
print ('Done')    
json_array

# %% [markdown]
# use the text search interface

# %% [markdown]
# # get all records that have a mereoritical_code value
# # have to use cursor pagination
#
# import pandas
# import time
#
# MINDAT_API_URL = "https://api.mindat.org"
# headers = {'Authorization': 'Token '+ YOUR_API_KEY}
#
# #fields_str = 'id','longid','guid','name'
#
# json_array = []
#
# params = {
#     'fields': fields_str, # put your selected fields here
#     'format': 'json',
#     'meteoritical_code_exists':'true'
# }
#
# response = requests.get(MINDAT_API_URL+"/geomaterials/",
#                 params=params,
#                 headers=headers)
#
# if 200 <= response.status_code <= 299:
#     json_out = response.json()
# #    print (json_out)
#     json_array = json_array + json_out["results"]
# else:
#     print ('problem')

# %%
json_array

# %%
params = {}

while json_out["next"] is not None :
    response = requests.get(json_out["next"],
                params=params,
                headers=headers)
    
    print (response.status_code)
    if 200 <= response.status_code <= 299:
        json_out = response.json()
    #    print (json_out)
        json_array = json_array + json_out["results"]
    else:
        print ('problem-- ', json_out["next"])

print ('Done')

# %%
df_result = pandas.DataFrame(json_array)

df_result.to_csv('timestamp.csv')

# %%
# Load the JSON array
# Create a DataFrame from results
df_nested_list = pandas.json_normalize(json_array, record_path =['results'])

# Display the DataFrame
print(df_nested_list)

# %%
df_nested_list.to_csv('49089.csv')

# %% [markdown]
# extract a list of ids and long-id for all minerals.

# %%
fields_str = 'id','longid'

params = {
    'fields': fields_str, # put your selected fields here
    'format': 'json'
}

response = requests.get(MINDAT_API_URL+"/geomaterials/",
                params=params,
                headers=headers)

if 200 <= response.status_code <= 299:
    json_out = response.json()
#    json_array.append(json_out)
else:
    print ('problem ')

# %% [markdown]
# same operation, but iterate through allpages.

# %%
# Create a DataFrame from results
df_nested_list = pandas.json_normalize(json_out, record_path =['results'])

# %%
json_out

# %%
df_nested_list.to_csv('id-longid.csv')

# %%
# mindat check sum algorithm
# from Jolyon,2023-06-18

def mindat_longid(authority, type, id):
    out = "{}:{}:{}:".format(authority, type, id)
    out2 = "{}{}{}".format(authority, type, id)
    t = 0
    for i in range(len(out2)):
        if i % 2 == 1:
            t += int(out2[i]) * 3
        else:
            t += int(out2[i])
    ck = t % 10
    if ck:
        ck = 10 - ck
    out += str(ck)
    return out

# %%
# run checksum function
mindat_longid(1,1,49602)

# %%
#from transformers import BertTokenizer

# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM, BertTokenizer,BertForSequenceClassification

#tokenizer = AutoTokenizer.from_pretrained('daven3/k2_fp_delta')
tokenizer = BertTokenizer.from_pretrained('allenai/scibert_scivocab_uncased', do_lower_case=True, use_fast=True)
#tokenizer = BertTokenizer.from_pretrained(//path to tokenizers)
sample = 'where is Himalayas in the world map?'
encoding = tokenizer.encode(sample)
print(encoding)
print(tokenizer.convert_ids_to_tokens(encoding))
